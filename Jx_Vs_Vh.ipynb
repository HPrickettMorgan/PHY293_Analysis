# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %%
data_dir = 'voltmeterdata_Ag.csv'
df = pd.read_csv(data_dir)
df
# Out:
#     Magnet Current (A)  B (T)  B uncertainty  I(mA)  I uncertainty  V(microV)  \
# 0                 1.59  0.547          0.003      4            0.1        1.7
# 1                 1.59  0.547          0.003      8            0.1        4.8
# 2                 1.59  0.547          0.003     10            0.1        5.6
# 3                 1.59  0.547          0.003     12            0.1        6.8
# 4                 1.59  0.547          0.003     14            0.1        8.3
# 5                 1.59  0.547          0.003     16            0.1        9.9
# 6                 1.59  0.547          0.003     20            0.1       13.1
# 7                 1.59  0.547          0.003     22            0.1       13.7
# 8                 1.59  0.547          0.003     24            0.1       15.9
# 9                 1.59  0.547          0.003     25            0.1       16.8
# 10                4.73  1.128          0.003      3            0.1        1.9
# 11                4.73  1.128          0.003      5            0.1        5.7
# 12                4.73  1.128          0.003      7            0.1       10.2
# 13                4.73  1.128          0.003      9            0.1       11.4
# 14                4.73  1.128          0.003     13            0.1       17.0
# 15                4.73  1.128          0.003     15            0.1       20.2
# 16                4.73  1.128          0.003     17            0.1       23.5
# 17                4.73  1.128          0.003     19            0.1       27.2
# 18                4.73  1.128          0.003     21            0.1       28.5
# 19                4.73  1.128          0.003     25            0.1       36.0
# 20                2.31  0.771          0.003      4            0.1        4.9
# 21                2.31  0.771          0.003      6            0.1        6.4
# 22                2.31  0.771          0.003     10            0.1        9.2
# 23                2.31  0.771          0.003     14            0.1       13.5
# 24                2.31  0.771          0.003     16            0.1       15.6
# 25                2.31  0.771          0.003     18            0.1       17.0
# 26                2.31  0.771          0.003     20            0.1       19.2
# 27                2.31  0.771          0.003     22            0.1       21.5
# 28                2.31  0.771          0.003     24            0.1       23.4
# 29                0.87  0.302          0.003      5            0.1        2.2
# 30                0.87  0.302          0.003      7            0.1        2.6
# 31                0.87  0.302          0.003     11            0.1        4.8
# 32                0.87  0.302          0.003     13            0.1        5.3
# 33                0.87  0.302          0.003     17            0.1        7.2
# 34                0.87  0.302          0.003     19            0.1        8.0
# 35                0.87  0.302          0.003     21            0.1        8.4
# 36                0.87  0.302          0.003     25            0.1        9.7
#
#     V uncertainty Voltmeter range
# 0             0.2         3microV
# 1             0.4        10microV
# 2             0.4        10microV
# 3             0.5        10microV
# 4             0.3        30microV
# 5             0.2        30microV
# 6             0.2        30microV
# 7             0.5        30microV
# 8             0.3        30microV
# 9             0.5        30microV
# 10            0.3        10microV
# 11            0.4        10microV
# 12            0.5        30microV
# 13            0.5        30microV
# 14            0.5        30microV
# 15            0.5        30microV
# 16            0.5        30microV
# 17            0.5        30microV
# 18            0.5        30microV
# 19            0.5       100microV
# 20            0.4        10microV
# 21            0.4        10microV
# 22            0.2        10microV
# 23            0.5        30microV
# 24            0.5        30microV
# 25            0.5        30microV
# 26            0.3        30microV
# 27            0.3        30microV
# 28            0.3        30microV
# 29            0.2        10microV
# 30            0.2        10microV
# 31            0.2        10microV
# 32            0.2        10microV
# 33            0.2        10microV
# 34            0.2        10microV
# 35            0.2        10microV
# 36            0.2        10microV

# %%
thickness = 1 #TODO: FIX
thickness_pct_uncertainty = 0 #TODO: FIX
width = 1 #TODO: FIX
width_pct_uncertainty = 0 #TODO: FIX

df['Jx'] = df['I(mA)'] / (width * thickness) # mA/mm^2
df['dJx'] = df['Jx'] * (
    (df['I uncertainty'] / df['I(mA)']) ** 2 + 
    thickness_pct_uncertainty ** 2 +
    width_pct_uncertainty ** 2
)**0.5

df.head()
# Out:
#    Magnet Current (A)  B (T)  B uncertainty  I(mA)  I uncertainty  V(microV)  \
# 0                1.59  0.547          0.003      4            0.1        1.7
# 1                1.59  0.547          0.003      8            0.1        4.8
# 2                1.59  0.547          0.003     10            0.1        5.6
# 3                1.59  0.547          0.003     12            0.1        6.8
# 4                1.59  0.547          0.003     14            0.1        8.3
#
#    V uncertainty Voltmeter range    Jx  dJx
# 0            0.2         3microV   4.0  0.1
# 1            0.4        10microV   8.0  0.1
# 2            0.4        10microV  10.0  0.1
# 3            0.5        10microV  12.0  0.1
# 4            0.3        30microV  14.0  0.1

# %%
df['Ey'] = -df['V(microV)'] / width

df['dEy'] = abs(
    df['Ey'] * (
        (df['V uncertainty'] / df['V(microV)']) ** 2 + 
        width_pct_uncertainty ** 2
    )**0.5
)

df.head()
# Out:
#    Magnet Current (A)  B (T)  B uncertainty  I(mA)  I uncertainty  V(microV)  \
# 0                1.59  0.547          0.003      4            0.1        1.7
# 1                1.59  0.547          0.003      8            0.1        4.8
# 2                1.59  0.547          0.003     10            0.1        5.6
# 3                1.59  0.547          0.003     12            0.1        6.8
# 4                1.59  0.547          0.003     14            0.1        8.3
#
#    V uncertainty Voltmeter range    Jx  dJx   Ey  dEy
# 0            0.2         3microV   4.0  0.1 -1.7  0.2
# 1            0.4        10microV   8.0  0.1 -4.8  0.4
# 2            0.4        10microV  10.0  0.1 -5.6  0.4
# 3            0.5        10microV  12.0  0.1 -6.8  0.5
# 4            0.3        30microV  14.0  0.1 -8.3  0.3

# %%
from scipy.stats import linregress
def calculate_linreg_features(df_group):
    m, b, r, p, std_err = linregress(df_group['Jx'], df_group['Ey'])
    
    # Calculate components of slope uncertainty
    N = len(df_group['Ey'])
    s_x = N * (df_group['Jx'] ** 2).sum() - df_group['Jx'].sum() ** 2 
    s_yx = (N-2)**-1 * ((df_group['Ey'] - (m * df_group['Jx'] + b)) ** 2).sum()

    # Calculate final uncertainties
    s_m = (N * s_yx / s_x) ** 0.5
    s_b = (s_yx * (df['Jx'] ** 2).sum() / s_x) ** 0.5
    
    return pd.Series({
        "Slope": m,
        "Slope Uncertainty": s_m,
        "Intercept": b,
        "Intercept Uncertainty": s_b
    })

# %%
linregs = df.groupby("B (T)").apply(calculate_linreg_features)
linregs.loc[0.302]
# Out:
# Slope                   -0.392489
# Slope Uncertainty        0.015913
# Intercept               -0.235788
# Intercept Uncertainty    0.551345
# Name: 0.302, dtype: float64

# %%
from numpy import linspace
fig, axs = plt.subplots(2,2)

fig.set_size_inches(16, 12)
for ix, (field_str, data) in enumerate(df.groupby('B (T)')):
    ax = axs[ix//2][ix%2]
    ax.errorbar(
        data['Jx'],
        data['Ey'], 
        xerr=data['dJx'],
        yerr=data['dEy'],
        capsize=3, 
        ecolor='r', 
        linestyle="None", 
        marker='o'
    )
    
    xs = linspace(df['Jx'].min(), df['Jx'].max(), 3)
    m = linregs.loc[field_str]['Slope']
    b = linregs.loc[field_str]['Intercept']
    ax.plot(xs, m * xs + b, color='orange', linestyle='--')

    ax.set_xlabel("Current Density (mA/mm^2)")
    ax.set_ylabel("Field Strength (microV/mm)")
    ax.set_title(f"B={field_str}")
